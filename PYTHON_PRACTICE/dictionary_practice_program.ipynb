# %% [markdown]
# ## Multi-Student University Evaluation

# %%
students = {
    "student_1": {
        "name": "Aman",
        "age": 20,
        "attendance": 91,
        "marks": {
            "python": 88,
            "sql": 76,
            "ml": 93,
            "math": 81
        },
        "assignments": {
            "python": 10,
            "sql": 8,
            "ml": 10,
            "math": 9
        },
        "scholarship": True
    },

    "student_2": {
        "name": "Riya",
        "age": 19,
        "attendance": 68,
        "marks": {
            "python": 91,
            "sql": 89,
            "ml": 94,
            "math": 87
        },
        "assignments": {
            "python": 10,
            "sql": 10,
            "ml": 10,
            "math": 10
        },
        "scholarship": True
    },

    "student_3": {
        "name": "Kabir",
        "age": 21,
        "attendance": 84,
        "marks": {
            "python": 42,
            "sql": 58,
            "ml": 39,
            "math": 61
        },
        "assignments": {
            "python": 7,
            "sql": 8,
            "ml": 6,
            "math": 9
        },
        "scholarship": False
    },

    "student_4": {
        "name": "Neha",
        "age": 22,
        "attendance": 96,
        "marks": {
            "python": 97,
            "sql": 94,
            "ml": 98,
            "math": 95
        },
        "assignments": {
            "python": 10,
            "sql": 10,
            "ml": 10,
            "math": 10
        },
        "scholarship": True
    }
}

# %%
student_name=str(input("Enter student name to evaluate:"))

if student_name==

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 students[0]
#
# KeyError: 0
