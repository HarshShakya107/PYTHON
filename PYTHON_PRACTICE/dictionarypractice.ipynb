# %% [markdown]
# Create a dictionary containing a person's name, age, and city. Print each value.

# %%
dicti={
    "name":"Harsh",
    "age":20,
    "city":"Sehore"
}
print(dict.values())
# Out:
# dict_values(['Harsh', 20, 'Sehore'])

# %%
names = ["A", "B", "C"]
scores = [80, 90, 75]
dict = {name: score for name, score in zip(names, scores)}
print(dict)
# Out:
# {'A': 80, 'B': 90, 'C': 75}

# %% [markdown]
# Given a dictionary of products and prices, find the product with the highest price.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       4 }
#       5 highest_price=dicti["price"][0]
#       6 higest_product=None
#       7 for product,price in dicti.items():
# ----> 8     if price>highest_price:
#       9         higest_product=product
#      10         highest_price=price
#      11 print(f"higest_price_product: {higest_product} and price is {highest_price}")
#
# TypeError: '>' not supported between instances of 'list' and 'int'
