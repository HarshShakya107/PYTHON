# %% [markdown]
# # getcwd()

# %%
import os

# %%
output=os.getcwd()
print(output)
# Out:
# c:\Users\HP\OneDrive\Desktop\GEN_AI_LEARNING\PYTHON\Learning\PYTHON_LEARNING

# %% [markdown]
# # mkdir()

# %%
output=os.mkdir("junk")

# %% [markdown]
# # listdir()

# %%
output=os.listdir(".")
print(output)
# Out:
# ['conditional_statment.ipynb', 'datatype.ipynb', 'dict.ipynb', 'file_handling.ipynb', 'functions.ipynb', 'list.ipynb', 'loops.ipynb', 'operators.ipynb', 'os.ipynb', 'set.ipynb', 'tuple.ipynb', 'variables.ipynb']

# %% [markdown]
# # join path

# %%
#os.path.join(dir_name,file_name)

# %% [markdown]
# # isfile()

# %%
os.path.isfile("os.ipynb")
# Out:
# True

# %% [markdown]
# # ifdir()

# %%
os.path.isdir("PYTHON_LEARNING")
# Out:
# False

# %% [markdown]
# # abspath()

# %%
os.path.abspath("os.ipynb")
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\GEN_AI_LEARNING\\PYTHON\\Learning\\PYTHON_LEARNING\\os.ipynb'
