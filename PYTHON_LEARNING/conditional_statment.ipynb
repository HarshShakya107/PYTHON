# %% [markdown]
# ### If

# %%
a=int(input("Enter one number"))
b=int(input("Enter another number please"))

if a>b:
    print("a is greater then b")
else:
    print("b is greater then a")
# Out:
# b is greater then a

# %% [markdown]
# ### Elif

# %%
a=int(input("Enter one number"))
b=int(input("Enter another number please"))
c=int(input("Enter third number"))

if a>b:
    print("a is greater then b")
elif a>c:
    print("a is greater then c")
else:
    print("a is smaller then b and c")
# Out:
# a is smaller then b and c
